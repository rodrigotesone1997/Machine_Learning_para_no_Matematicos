# %% [markdown]
# # Importamos los paquetes necesarios

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from warnings import filterwarnings

# %% [markdown]
# # Removemos las advertencias

# %%
filterwarnings('ignore')

# %% [markdown]
# # Defino Dataframe

# %%
file= 'train.csv'

df= pd.read_csv(file)

# %% [markdown]
# # Defino ancho y alto de las imágenes

# %%
ancho = 8
alto  = 5

# %% [markdown]
# # Único punto

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1]
y = df['SalePrice'].iloc[1]

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Dato medido")
plt.plot((x,x),(y,172500),linestyle="--",color="black")
plt.plot((x,1200),(y,y),linestyle="--",color="cyan")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Definimos los límites de los ejes

plt.xlim((1200,1320))
plt.ylim((172000, 190000))

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Guardamos la imagen en determinada ubicación

plt.savefig('unico_punto.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # 2 Puntos

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1:3]
y = df['SalePrice'].iloc[1:3]

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Datos medidos")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)
  
# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Definimos los límites de los ejes

plt.xlim((1000,2500))

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Guardamos la imagen en determinada ubicación

plt.savefig('2_puntos.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Recta

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1:3]
y = df['SalePrice'].iloc[1:3]              

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Datos medidos")
plt.plot(x, y,label="Recta")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Agregamos una etiqueta

plt.legend(loc ="lower right")

# Guardamos la imagen en determinada ubicación

plt.savefig('recta.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Definimos la recta con esos 2 puntos

# %%
def recta(x_fun):
    return ((y[0]-y[1])/(x[0]-x[1]))*x_fun+y[0]-x[0]*((y[0]-y[1])/(x[0]-x[1]))

# %% [markdown]
# # Predicción del valor 1500

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1:3].tolist()
y = df['SalePrice'].iloc[1:3].tolist()

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Datos medidos")
plt.scatter(1500, recta(1500),color="black",label="Valor predecio\npor la recta")
plt.plot(x,y,alpha=0.5,label="Recta")
plt.plot((1500,1500),(0, recta(1500)),linestyle="--")
plt.plot((1500,1000),(recta(1500), recta(1500)),linestyle="--")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Agregamos una etiqueta

plt.legend(loc ="lower right")

# Guardamos la imagen en determinada ubicación

plt.savefig('prediccion_valor_1500.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # 3 Puntos

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1:4].tolist()
y = df['SalePrice'].iloc[1:4].tolist()

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Datos medidos")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Definimos los límites de los ejes

plt.xlim((1000,2500))

# Guardamos la imagen en determinada ubicación

plt.savefig('3_puntos.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # 10 Puntos

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1:11].tolist()
y = df['SalePrice'].iloc[1:11].tolist()

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Datos medidos")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Definimos los límites de los ejes

plt.xlim((500,3000))

# Guardamos la imagen en determinada ubicación

plt.savefig('10_puntos.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Todos los puntos

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].tolist()
y = df['SalePrice'].tolist()

# Hacemos las graficas

plt.scatter(x, y,color="red",label="Datos medidos")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Definimos los límites de los ejes

plt.xlim((0,8000))

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Guardamos la imagen en determinada ubicación

plt.savefig('todos_los_puntos.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Plano x-y

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Hacemos las graficas

plt.scatter(x, y,color="violet")
for i,j in zip(x,y):
    plt.plot((i,i),(j,0),color="orange",linestyle="--")
    plt.plot((i,0),(j,j),color="orange",linestyle="--")

# Nombre del eje x

plt.xlabel('x',fontsize=15)

# Nombre del eje y

plt.ylabel('y',fontsize=15)

# Agregamos un título al grafico

plt.title('Plano x - y',fontsize=25)

# Definimos los límites de los ejes

plt.xlim(-0.1,5)
plt.ylim(-0.1,10)

# Guardamos la imagen en determinada ubicación

plt.savefig('plano_x_y.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Recta de Prueba

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Hacemos las graficas

plt.scatter(x, y,color="violet")
plt.plot(x,y)

# Nombre del eje x

plt.xlabel('x',fontsize=15)

# Nombre del eje y

plt.ylabel('y',fontsize=15)

# Agregamos un título al grafico

plt.title('Plano x - y',fontsize=25)

# Definimos los límites de los ejes

plt.xlim(-0.1,5)
plt.ylim(-0.1,10)

# Guardamos la imagen en determinada ubicación

plt.savefig('recta_de_prueba.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Distintas pendientes

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x_1 = np.arange(5)

def y_1(x):
    return 2*x
def y_2(x):
    return 3*x
def y_3(x):
    return 4*x
def y_4(x):
    return 5*x
def y_5(x):
    return 6*x
def y_6(x):
    return 1*x
def y_7(x):
    return 0.5*x
def y_8(x):
    return 0.1*x

# Hacemos las graficas

plt.plot(x_1,y_8(x_1),label="$y=0.1\cdot x$",color="violet")
plt.plot(x_1,y_7(x_1),label="$y=0.5\cdot x$",color="orange")
plt.plot(x_1,y_6(x_1),label="$y=1\cdot x$",color="green")
plt.plot(x_1,y_1(x_1),label="$y=2\cdot x$",color="yellow")
plt.plot(x_1,y_2(x_1),label="$y=3\cdot x$",color="brown")
plt.plot(x_1,y_3(x_1),label="$y=4\cdot x$",color="black")
plt.plot(x_1,y_4(x_1),label="$y=5\cdot x$",color="cyan")
plt.plot(x_1,y_5(x_1),label="$y=6\cdot x$",color="blue")

# Nombre del eje x

plt.xlabel('x',fontsize=15)

# Nombre del eje y

plt.ylabel('y',fontsize=15)

# Agregamos un título al grafico

plt.title('Plano x - y',fontsize=25)

# Definimos los límites de los ejes

plt.xlim(-0.1,10)
plt.ylim(-0.1,10)

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Guardamos la imagen en determinada ubicación

plt.savefig('distintas_pendientes.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Distinta ordenada al origen

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x_1 = np.arange(-5,5)

def y_1(x):
    return x-3
def y_2(x):
    return x-2
def y_3(x):
    return x-1
def y_4(x):
    return x
def y_5(x):
    return x+1
def y_6(x):
    return x+2
def y_7(x):
    return x+3

# Hacemos las graficas

plt.plot(x_1,y_1(x_1),label="$y=x-3$",color="violet")
plt.plot(x_1,y_2(x_1),label="$y=x-2$",color="orange")
plt.plot(x_1,y_3(x_1),label="$y=x-1$",color="green")
plt.plot(x_1,y_4(x_1),label="$y=x$",color="yellow")
plt.plot(x_1,y_5(x_1),label="$y=x+1$",color="brown")
plt.plot(x_1,y_6(x_1),label="$y=x+2$",color="black")
plt.plot(x_1,y_7(x_1),label="$y=x+3$",color="cyan")

# Nombre del eje x

plt.xlabel('x',fontsize=15)

# Nombre del eje y

plt.ylabel('y',fontsize=15)

# Agregamos un título al grafico

plt.title('Plano x - y',fontsize=25)

# Definimos los límites de los ejes

plt.xlim(-5,10)
plt.ylim(-5,10)

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Guardamos la imagen en determinada ubicación

plt.savefig('distinta_ordenada_al_origen.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Código de Regresión Lineal simple

# %%
# Importo los paquetes necesarios para la Regresión lineal

from  sklearn.model_selection  import  train_test_split
from  sklearn.linear_model  import  LinearRegression

# Defino como dataframe el archivo de entrenamiento

df = pd.read_csv("train.csv")

# Defino los valores de la variable independiente y la dependiente

x = df["GrLivArea"].values.reshape(-1,1)
y = df["SalePrice"].values.reshape(-1,1)

# Entrenamos el set de  datos
# El  modulo train_test_split recibe el set de datos, los divide en
# 2 partes (en este caso es un 80 % de entrenamiento y
# 20 % de testeo) y asi se tiene separados los datos para
# entrenar el modelo y testearlo

X_train , X_test , y_train , y_test = train_test_split(x, y,
                                                       test_size =0.2,random_state=0)

# Inicializo la clase LinearRegression

modelo = LinearRegression()

# En esta línea se entrena el modelo, es decir, le damos los  datos
# al modelo y asi obtener los valores de la recta

modelo.fit(X_train , y_train)

# Obtenemos la pendiente redondeada a 2 decimales:

pendiente=round(modelo.coef_[0][0] ,2)
print(f"La pendiente (m) de la recta es: {pendiente}\n")

# Obtenemos  la  ordenada  al  origen  redondeada a 2 decimales:

ordenada_al_origen=round(modelo.intercept_ [0],2)
print(f"La ordenada al origen (h) de la recta es: {ordenada_al_origen}\n")

# Obtenemos la eficiencia del modelo

eficiencia_modelo=round(modelo.score(X_test,y_test),2)*100
print(f"El modelo tiene una eficiencia del {eficiencia_modelo} %")

# %% [markdown]
# # Valuamos el modelo en x = 4000

# %%
prediccion=pendiente*4000+ordenada_al_origen

print(f"El modelo valuado en x = 4000 pies cuadrados es {prediccion} dólares.")

# %% [markdown]
# # Recta Final

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Defino los valores de la variable independiente y la dependiente

y_pred = modelo.predict(x)

# Hacemos las graficas

plt.scatter(x,y,color="red",alpha=0.2, label="Mediciones")
plt.plot(x, y_pred, color='blue', linewidth=2,label="Modelo")

# Agregamos una etiqueta

plt.legend(loc ="upper right")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=15)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=15)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=25)

# Guardamos la imagen en determinada ubicación

plt.savefig('recta_final.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Error

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho, alto))

# Puntos para graficar

x = df['GrLivArea'].iloc[1:11].tolist()
y = df['SalePrice'].iloc[1:11].tolist()
x_fun=df['GrLivArea']

# Hacemos las graficas

plt.scatter(x, y,color="red")
plt.plot(x_fun, recta(x_fun))
for i,j in zip(x,y):
    plt.plot((i,i),(j, recta(i)),linestyle="--",color="black")

# Nombre del eje x

plt.xlabel('Área [pies cuadrados]',fontsize=10)

# Nombre del eje y

plt.ylabel('Precio [dólares]',fontsize=10)

# Agregamos un título al grafico

plt.title('Relación Área - Precio',fontsize=20)

# Definimos los limites de los ejes

plt.xlim((500, 2500))
plt.ylim(0,350000)

# Guardamos la imagen en determinada ubicación

plt.savefig('error.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Defino ancho y alto de las imágenes

# %%
ancho_3d = 10
alto_3d  = 12

# %% [markdown]
# # Ubicación en x

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho_3d, alto_3d))
ax = fig.gca(projection='3d')

# Puntos para graficar

x = np.array(df['GrLivArea'].iloc[20:21])
y = np.array(df["GarageArea"].iloc[20:21])
z = np.array(df['SalePrice'].iloc[20:21])

# Hacemos las graficas

ax.scatter(x, y, z,color="red")
for i,j,k in zip(x,y,z):
    plt.plot((i,i) , (8000,j) , (0,0) ,linestyle="--",color="black",linewidth=2)

# Nombre del eje x

ax.set_xlabel('\nÁrea propiedad',fontsize=15)

# Nombre del eje y

ax.set_ylabel('Área garage\n\n',fontsize=15)

# Nombre del eje z

ax.set_zlabel('Precio\n\n',fontsize=15)

# Agregamos un título al grafico

ax.set_title('Relación \nÁrea de la propiedad [pies cuadrados] - \nÁrea del garage [pies cuadrados] - \nPrecio [dólares]',fontsize=20)

# Desactivamos las marcas del eje z

ax.set_zticks([])

# Desactivamos la rotación automática de la etiqueta z

ax.zaxis.set_rotate_label(False)

# Definimos el ángulo de la imagen

ax.view_init(90,90)

# Definimos los límites de los ejes

ax.axes.set_xlim3d(left=0, right=8000)
ax.axes.set_ylim3d(bottom=0, top=8000)
ax.axes.set_zlim3d(bottom=0, top=1000000)

# Guardamos la imagen en determinada ubicación

plt.savefig('ubicacion_en_x.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Ubicación en y

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho_3d, alto_3d))
ax = fig.gca(projection='3d')

# Puntos para graficar

x = np.array(df['GrLivArea'].iloc[20:21])
y = np.array(df["GarageArea"].iloc[20:21])
z = np.array(df['SalePrice'].iloc[20:21])

# Hacemos las graficas

ax.scatter(x, y, z,color="red")
for i,j,k in zip(x,y,z):
    plt.plot((i,i) , (8000,j) , (0,0) ,linestyle="--",color="black",linewidth=2)
    plt.plot((8000,i) , (j,j) , (0,0) ,linestyle="--",color="cyan",linewidth=2)

# Nombre del eje x

ax.set_xlabel('\nÁrea propiedad',fontsize=15)

# Nombre del eje y

ax.set_ylabel('Área garage\n\n',fontsize=15)

# Nombre del eje z

ax.set_zlabel('Precio\n\n',fontsize=15)

# Agregamos un título al grafico

ax.set_title('Relación \nÁrea de la propiedad [pies cuadrados] - \nÁrea del garage [pies cuadrados] - \nPrecio [dólares]',fontsize=20)

# Desactivamos las marcas del eje z

ax.set_zticks([])

# Desactivamos la rotación automática de la etiqueta z

ax.zaxis.set_rotate_label(False)

# Definimos el ángulo de la imagen

ax.view_init(90,90)

# Definimos los límites de los ejes

ax.axes.set_xlim3d(left=0, right=8000)
ax.axes.set_ylim3d(bottom=0, top=8000)
ax.axes.set_zlim3d(bottom=0, top=1000000)

# Guardamos la imagen en determinada ubicación

plt.savefig('ubicacion_en_y.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Ubicación en z

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho_3d, alto_3d))
ax = fig.gca(projection='3d')

# Puntos para graficar

x = np.array(df['GrLivArea'].iloc[20:21])
y = np.array(df["GarageArea"].iloc[20:21])
z = np.array(df['SalePrice'].iloc[20:21])

# Hacemos las graficas

ax.scatter(x, y, z,color="red")
for i,j,k in zip(x,y,z):
    plt.plot((i,i) , (8000,j) , (0,0) ,linestyle="--",color="black",linewidth=2)
    plt.plot((8000,i) , (j,j) , (0,0) ,linestyle="--",color="cyan",linewidth=2)
    plt.plot((i,i) , (j,j) , (0,z) ,linestyle="--",color="orange",linewidth=2)

# Agregamos un título al grafico

ax.set_title('Relación \nÁrea de la propiedad [pies cuadrados] - \nÁrea del garage [pies cuadrados] - \nPrecio [dólares]',fontsize=20)

# Nombre del eje x

ax.set_xlabel('\nÁrea propiedad ',fontsize=15)

# Nombre del eje y

ax.set_ylabel('Área garage\n',fontsize=15)

# Nombre del eje z

ax.set_zlabel('Precio\n\n',rotation=90,fontsize=15)

# Desactivamos la rotación automática de la etiqueta z

ax.zaxis.set_rotate_label(False)

# Definimos el ángulo de la imagen

ax.view_init(20,90)

# Definimos los límites de los ejes

ax.axes.set_xlim3d(left=0, right=8000)
ax.axes.set_ylim3d(bottom=0, top=8000)
ax.axes.set_zlim3d(bottom=0, top=1000000)

# Guardamos la imagen en determinada ubicación

plt.savefig('ubicacion_en_z.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Gráfico Final

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho_3d, alto_3d))
ax = fig.gca(projection='3d')

# Puntos para graficar

x = df['GrLivArea']
y = df["GarageArea"]
z = df['SalePrice']

# Hacemos las graficas

ax.scatter(x, y, z,color="red")

# Nombre del eje x

ax.set_xlabel('\nÁrea propiedad',fontsize=15)

# Nombre del eje y

ax.set_ylabel('Área garage\n\n',fontsize=15)

# Nombre del eje z

ax.set_zlabel('Precio\n\n',rotation=90,fontsize=15)

# Agregamos un título al grafico

ax.set_title('Relación \nÁrea de la propiedad [pies cuadrados] - \nÁrea del garage [pies cuadrados] - \nPrecio [dólares]',fontsize=20)

# Desactivamos la rotación automática de la etiqueta z

ax.zaxis.set_rotate_label(False)

# Definimos el ángulo de la imagen

ax.view_init(15,90)

# Definimos los límites de los ejes

ax.axes.set_xlim3d(left=0, right=8000)
ax.axes.set_ylim3d(bottom=0, top=2000)
ax.axes.set_zlim3d(bottom=0, top=1000000)

# Guardamos la imagen en determinada ubicación

plt.savefig('grafico_final.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Plano

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho_3d, alto_3d))
ax = fig.gca(projection='3d')

# Puntos para graficar

x = np.linspace(-1,1,10)
y = np.linspace(-1,1,10)
X,Y = np.meshgrid(x,y)
Z=0.12861723162963065*X + 0.0014024845304814665*Y + 1.0964608113924048

# Hacemos las graficas

ax.plot_surface(X, Y, Z)

# Nombre del eje x

ax.set_xlabel('x',fontsize=15)

# Nombre del eje y

ax.set_ylabel('y ',fontsize=15)

# Nombre del eje z

ax.set_zlabel('z\n',rotation=90,fontsize=15)

# Agregamos un título al grafico

ax.set_title('Relacion x-y-z',fontsize=25)

# Definimos el ángulo de la imagen

ax.view_init(45,90)

# Guardamos la imagen en determinada ubicación

plt.savefig('plano.png')

# Mostramos el gráfico

plt.show()

# %% [markdown]
# # Código de Regresión Lineal múltiple

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=pd.read_csv(file)

X = df[['GrLivArea', 'GarageArea']].values.reshape(-1,2)
Y = df['SalePrice']

X_train , X_test , y_train , y_test = train_test_split(X, Y,
                                        test_size =0.2,random_state=0)

modelo= LinearRegression()
modelo.fit(X_train, y_train)

a=round(modelo.coef_[0],2)
b=round(modelo.coef_[1],2)
c=round(modelo.intercept_,2)
eficiencia_modelo= round(modelo.score(X_test, y_test)*100,2)

print(f"El coeficiente \"a\" del plano es: {a}\n")
print(f"El coeficiente \"b\" del plano es: {b}\n")
print(f"El coeficiente \"c\" del plano es: {c}\n")
print(f"El modelo tiene una eficiencia del {eficiencia_modelo} %")

# %% [markdown]
# # Plano aproximación

# %%
# Contenedor de la imagen

fig = plt.figure(figsize=(ancho_3d, alto_3d))
ax = fig.gca(projection='3d')

# Puntos para graficar

x = X[:, 0]
y = X[:, 1]
z = Y

# Hacemos las graficas

ax.scatter(x, y, z,color="red",alpha=0.2)

# Puntos para graficar

x,y = np.meshgrid(x,y)
Z=a*x+ b*y +c

# Hacemos las graficas

ax.plot_surface(x, y, Z)

# Nombre del eje x

ax.set_xlabel('\nÁrea propiedad',fontsize=15)

# Nombre del eje y

ax.set_ylabel('Área garage\n\n',fontsize=15)

# Nombre del eje z

ax.set_zlabel('Precio\n\n\n\n',rotation=90,fontsize=15)

# Agregamos un título al grafico

ax.set_title('Relación \nÁrea de la propiedad [pies cuadrados] - \nÁrea del garage [pies cuadrados] - \nPrecio [dólares]',fontsize=20)

# Desactivamos la rotación automática de la etiqueta z

ax.zaxis.set_rotate_label(False)

# Definimos el ángulo de la imagen

ax.view_init(25,90)

# Definimos los límites de los ejes

ax.axes.set_xlim3d(left=0, right=8000)
ax.axes.set_ylim3d(bottom=0, top=2000)
ax.axes.set_zlim3d(bottom=0, top=1000000)

# Guardamos la imagen en determinada ubicación

plt.savefig('plano_aproximacion.png')

# Mostramos el gráfico

plt.show()
